# %% [markdown]
# # NEURAL NETWORK

# %% [markdown]
# Neural Network mengadopsi dari kemampuan otak manusia yang mampu memberikan stimulasi/rangsangan, melakukan proses, dan memberikan output. Output diperoleh dari variasi stimulasi dan proses yang terjadi di dalam otak manusia. Kemampuan manusia dalam memproses informasi merupakan hasil kompleksitas proses di dalam otak. Misalnya, yang terjadi pada anak-anak, mereka mampu belajar untuk melakukan pengenalan meskipun mereka tidak mengetahui algoritma apa yang digunakan.
#
# Dari struktur neuron pada otak manusia, dan proses kerja yang dijelaskan di atas, maka konsep dasar pembangunan neural network buatan (Artificial Neural Network) terbentuk. Ide mendasar dari Artificial Neural Network (ANN) adalah mengadopsi mekanisme berpikir sebuah sistem atau aplikasi yang menyerupai otak manusia, baik untuk pemrosesan berbagai sinyal elemen yang diterima, toleransi terhadap kesalahan/error, dan juga parallel processing.
#
# ![image.png](attachment:image.png)
#
# Ada beberapa konsep kunci dalam Neural Network:
#
#     Neuron (Node): Unit pemrosesan dasar dalam Neural Network. Setiap neuron menerima beberapa input, melakukan operasi matematika tertentu, dan menghasilkan output. Ini meniru cara neuron biologis berkomunikasi dengan satu sama lain.
#
#     Bobot (Weights): Setiap koneksi antara neuron dalam Neural Network memiliki bobot yang mengatur seberapa pentingnya input tersebut untuk neuron penerima. Bobot-bobot ini diperbarui selama proses pelatihan untuk mengoptimalkan kinerja jaringan.
#
#     Fungsi Aktivasi: Fungsi ini digunakan oleh setiap neuron untuk menambahkan non-linearitas ke dalam jaringan. Ini diperlukan agar Neural Network dapat memodelkan hubungan yang kompleks antara input dan output. Beberapa fungsi aktivasi yang umum digunakan termasuk sigmoid, ReLU (Rectified Linear Unit), tanh, dan softmax.
#
#     Lapisan (Layers): Neural Network terdiri dari beberapa lapisan neuron yang disusun secara hierarkis. Lapisan input menerima data masukan, lapisan output menghasilkan prediksi atau output, dan lapisan-lapisan di antaranya disebut lapisan tersembunyi (hidden layers). Setiap lapisan terhubung ke lapisan di sekitarnya melalui koneksi yang mengandung bobot.
#
#     Feedforward dan Backpropagation: Proses feedforward adalah proses di mana sinyal input mengalir melalui jaringan dari lapisan input ke lapisan output, menghasilkan output prediksi. Proses backpropagation adalah proses yang digunakan untuk melatih jaringan dengan menghitung gradien dari fungsi kerugian terhadap bobot dan memperbarui bobot menggunakan metode gradien turunan.

# %% [markdown]
# ## Multi Layer Perceptron

# %% [markdown]
# MLP adalah jenis Neural Network yang paling dasar, yang terdiri dari beberapa lapisan neuron, termasuk setidaknya satu lapisan tersembunyi di antaranya. Berikut adalah contoh struktur MLP:
#
#     Input Layer: Lapisan pertama dalam MLP, menerima data masukan.
#     Hidden Layers: Lapisan-lapisan di antara lapisan input dan output yang melakukan operasi pemrosesan terhadap data masukan.
#     Output Layer: Lapisan terakhir dalam MLP, menghasilkan output prediksi.

# %%
# Import Library
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix
from sklearn.neural_network import MLPClassifier

# %%
# Load dataset Iris
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Inisialisasi Model MLP
nn_model = MLPClassifier()

# %%
# Lakukan cross-validation dengan 5 fold
scoring = ['accuracy', 'precision_macro', 'recall_macro', 'f1_macro']
scores = cross_validate(nn_model, X, y, cv=5, scoring=scoring)
# Out:
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Hitung confusion matrix dari prediksi cross-validation
cm = confusion_matrix(y, cross_val_predict(nn_model, X, y, cv=5))

# Visualisasikan confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, cmap='Blues', fmt='g', xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix (Cross-Validation)')
plt.show()
# Out:
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Ariful\anaconda3\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Tampilkan hasil cross-validation
print("Hasil Cross-Validation:")
print("Akurasi:", np.mean(scores['test_accuracy']))
print("Precision:", np.mean(scores['test_precision_macro']))
print("Recall:", np.mean(scores['test_recall_macro']))
print("F1 Score:", np.mean(scores['test_f1_macro']))
# Out:
# Hasil Cross-Validation:
# Akurasi: 0.9666666666666668
# Precision: 0.9717171717171718
# Recall: 0.9666666666666666
# F1 Score: 0.9663805979595452

# %% [markdown]
# ## Backpropagation Neural Network (BPNN)

# %% [markdown]
# Backpropagation Neural Network (BPNN) adalah jenis jaringan saraf tiruan yang menggunakan algoritma backpropagation untuk melatih modelnya.
#
# Struktur Jaringan:
#
#     Terdiri dari beberapa lapisan: lapisan input, satu atau lebih lapisan tersembunyi, dan lapisan output.
#     Setiap neuron di satu lapisan terhubung ke neuron di lapisan berikutnya dengan bobot tertentu.
#
#
#
# Algoritma Backpropagation:
# Merupakan metode pembelajaran supervised yang menggunakan algoritma gradient descent untuk meminimalkan error antara output prediksi dan target.
# Proses pelatihan terdiri dari dua tahap utama:
#         1. Forward pass: Data input diproses maju melalui jaringan untuk menghasilkan output.
#         2. Backward pass: Error dihitung dan disebarkan mundur melalui jaringan untuk memperbarui bobot menggunakan turunan fungsi loss terhadap bobot (gradient).

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score, classification_report 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# Load dataset Iris
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# %%
# Normalisasi fitur
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
# One-hot encoding untuk label
encoder = OneHotEncoder(sparse_output=False)
y_onehot = encoder.fit_transform(y)

# %%
# Bagi data menjadi train dan test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_onehot, test_size=0.3, random_state=42)

# %%
# Bangun model BPNN (MLP dengan backpropagation)
model = Sequential()
model.add(Dense(10, input_dim=4, activation='relu'))  # Hidden layer dengan 10 neuron
model.add(Dense(10, activation='relu'))               # Hidden layer kedua
model.add(Dense(3, activation='softmax'))              # Output layer (3 kelas)
# Out:
# c:\Users\Ariful\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Kompilasi model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Latih model
history = model.fit(X_train, y_train, epochs=100, batch_size=5, verbose=1, validation_split=0.2)
# Out:
# Epoch 1/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.2643 - loss: 1.2852 - val_accuracy: 0.4762 - val_loss: 1.1468
# Epoch 2/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3549 - loss: 1.2300 - val_accuracy: 0.5238 - val_loss: 1.1073
# Epoch 3/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4533 - loss: 1.1575 - val_accuracy: 0.5238 - val_loss: 1.0764
# Epoch 4/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4500 - loss: 1.1361 - val_accuracy: 0.6190 - val_loss: 1.0480
# Epoch 5/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5534 - loss: 1.0803 - val_accuracy: 0.6190 - val_loss: 1.0200
# Epoch 6/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5250 - loss: 1.0371 - val_accuracy: 0.6190 - val_loss: 0.9941
# Epoch 7/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4648 - loss: 1.0201 - val_accuracy: 0.6190 - val_loss: 0.9661
# Epoch 8/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4666 - loss: 0.9984 - val_accuracy: 0.6190 - val_loss: 0.9346
# Epoch 9/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5005 - loss: 0.9486 - val_accuracy: 0.7619 - val_loss: 0.8990
# Epoch 10/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9483 - loss: 0.1365 - val_accuracy: 0.9048 - val_loss: 0.2562
# Epoch 78/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9298 - loss: 0.1399 - val_accuracy: 0.9524 - val_loss: 0.2569
# Epoch 79/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9334 - loss: 0.1217 - val_accuracy: 0.9524 - val_loss: 0.2570
# Epoch 80/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9579 - loss: 0.1243 - val_accuracy: 0.9524 - val_loss: 0.2481
# Epoch 81/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.1459 - val_accuracy: 0.9524 - val_loss: 0.2426
# Epoch 82/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9605 - loss: 0.1172 - val_accuracy: 0.9524 - val_loss: 0.2518
# Epoch 83/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9598 - loss: 0.1248 - val_accuracy: 0.9524 - val_loss: 0.2481
# Epoch 84/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9698 - loss: 0.1179 - val_accuracy: 0.9524 - val_loss: 0.2521
# Epoch 85/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9609 - loss: 0.1311 - val_accuracy: 0.9524 - val_loss: 0.2402
# Epoch 86/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.1139 - val_accuracy: 0.9524 - val_loss: 0.2260
# Epoch 87/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9740 - loss: 0.0860 - val_accuracy: 0.9524 - val_loss: 0.2292
# Epoch 88/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9625 - loss: 0.1051 - val_accuracy: 0.9524 - val_loss: 0.2258
# Epoch 89/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9353 - loss: 0.1042 - val_accuracy: 0.9524 - val_loss: 0.2340
# Epoch 90/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9864 - loss: 0.1146 - val_accuracy: 0.9524 - val_loss: 0.2145
# Epoch 91/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9711 - loss: 0.0968 - val_accuracy: 0.9524 - val_loss: 0.2256
# Epoch 92/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9846 - loss: 0.0734 - val_accuracy: 0.9524 - val_loss: 0.2216
# Epoch 93/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9659 - loss: 0.0893 - val_accuracy: 0.9524 - val_loss: 0.2222
# Epoch 94/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1334 - val_accuracy: 0.9524 - val_loss: 0.2117
# Epoch 95/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9448 - loss: 0.1261 - val_accuracy: 0.9524 - val_loss: 0.2186
# Epoch 96/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9784 - loss: 0.0871 - val_accuracy: 0.9524 - val_loss: 0.2089
# Epoch 97/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9787 - loss: 0.0735 - val_accuracy: 0.9524 - val_loss: 0.2045
# Epoch 98/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9382 - loss: 0.1433 - val_accuracy: 0.9524 - val_loss: 0.2132
# Epoch 99/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9801 - loss: 0.0970 - val_accuracy: 0.9524 - val_loss: 0.2023
# Epoch 100/100
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9572 - loss: 0.1246 - val_accuracy: 0.9524 - val_loss: 0.2026

# %%
# Evaluasi model pada data test
loss, accuracy = model.evaluate(X_test, y_test, verbose=0)
print(f'\nTest Accuracy: {accuracy:.4f}')
# Out:
# Test Accuracy: 1.0000

# %%
# Prediksi contoh
y_pred = model.predict(X_test)
predicted_classes = np.argmax(y_pred, axis=1)
true_classes = np.argmax(y_test, axis=1)

true_classes = np.argmax(y_test, axis=1)
predicted_classes = np.argmax(y_pred, axis=1)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
# Hitung confusion matrix
cm = confusion_matrix(true_classes, predicted_classes)

# Tampilkan confusion matrix dengan visualisasi
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=iris.target_names)
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix - BPNN on Iris Dataset')
plt.show()

true_classes = np.argmax(y_test, axis=1)
predicted_classes = np.argmax(y_pred, axis=1)

# %%
# Hitung akurasi
accuracy = accuracy_score(true_classes, predicted_classes)
print(f'Akurasi: {accuracy:.4f}')

# Tampilkan classification report
report = classification_report(true_classes, predicted_classes, target_names=iris.target_names)
print('\nClassification Report:')
print(report)
# Out:
# Akurasi: 1.0000
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
